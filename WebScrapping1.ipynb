# %%
#Import libraries
import requests
from bs4 import BeautifulSoup

# %%
req = requests.get('https://www.daraz.pk/led-tvs/samsung/')

# %%
soup = BeautifulSoup(req.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="a2a0e" name="data-spm"/>
#   <meta content="notranslate" name="google">
#    <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#    <meta content="width=device-width" name="viewport"/>
#    <link href="//laz-g-cdn.alicdn.com" rel="dns-prefetch"/>
#    <link href="//laz-img-cdn.alicdn.com" rel="dns-prefetch"/>
#    <title>
#     Samsung Led Tv Price In Pakistan - 12 Months 0% EMI Plans
#    </title>
#    <meta content="Samsung Led Tv at best price in Pakistan from daraz.pk. Shop online for Samsung Led Tv in Pakistan and get delivery in Karachi, Lahore, Islamabad and countrywide." name="description"/>
#    <meta content="25ZiIC89hBvAEL0Sgu7Ffw07GXU_d4CXtFvWyK3wMjo" name="google-site-verification"/>
#    <meta content="index, follow" name="robots"/>
# ...

# %%
ins1 = soup.title
print(ins1.get_text())
# Out:
# Samsung Led Tv Price In Pakistan - 12 Months 0% EMI Plans

# %%
ins2 = soup.find_all("div", class_="get-the-app-title")
ins2
# Out:
# [<div class="get-the-app-title">Download the App</div>]
